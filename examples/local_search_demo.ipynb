# %%
import os
import logging
from typing import Any, Set

from automata.config.base import AgentConfigName
from automata.singletons.dependency_factory import dependency_factory, DependencyFactory
from automata.singletons.py_module_loader import py_module_loader
from automata.context_providers.symbol_synchronization import (
    SymbolProviderSynchronizationContext,
)
from automata.symbol.graph import SymbolGraph
from automata.symbol_embedding.vector_databases import (
    ChromaSymbolEmbeddingVectorDatabase,
)
from automata.symbol_embedding.base import SymbolCodeEmbedding, SymbolDocEmbedding
from automata.llm.providers.openai import OpenAIEmbeddingProvider
from automata.experimental.search.rank import SymbolRank, SymbolRankConfig

logger = logging.getLogger(__name__)

# %%
root_path = "/Users/ocolegrove/repo_store/llama_index"
project_name = "llama_index"


root_path = "/Users/ocolegrove/AutomataNoCruft"
project_name = "automata"
py_module_loader.initialize(root_path, project_name)

# %%
code_embedding_db = ChromaSymbolEmbeddingVectorDatabase(
    project_name,
    persist_directory=DependencyFactory.DEFAULT_CODE_EMBEDDING_FPATH,
    factory=SymbolCodeEmbedding.from_args,
)

symbol_graph = SymbolGraph(
    os.path.join(DependencyFactory.DEFAULT_SCIP_FPATH, f"{project_name}.scip")
)
embedding_provider = OpenAIEmbeddingProvider()

dependency_factory.set_overrides(
    **{
        "symbol_graph": symbol_graph,
        "code_embedding_db": code_embedding_db,
        "embedding_provider": embedding_provider,
    }
)
# Out:
# self.overrides.get("disable_synchronization", False) =  False
# provider =  <automata.symbol.graph.SymbolGraph object at 0x159f05b50>
# self.overrides =  {'symbol_graph': <automata.symbol.graph.SymbolGraph object at 0x159f05b50>, 'code_embedding_db': <automata.symbol_embedding.vector_databases.ChromaSymbolEmbeddingVectorDatabase object at 0x159f05ac0>, 'embedding_provider': <automata.llm.providers.openai.OpenAIEmbeddingProvider object at 0x10808cfd0>}

# %%
from automata.symbol.symbol_utils import get_rankable_symbols
filtered_symbols = get_rankable_symbols(symbol_graph.get_sorted_supported_symbols())
print(f'len(filtered_symbols) = {len(filtered_symbols)}')
# Out:
# len(filtered_symbols) = 645

# %%
from automata.symbol.symbol_utils import convert_to_ast_object, get_rankable_symbols
filtered_symbols = get_rankable_symbols(symbol_graph.get_sorted_supported_symbols())
print(f'len(filtered_symbols) = {len(filtered_symbols)}')
# Out:
# len(filtered_symbols) = 0

# %%
for i,filtered_symbol in enumerate(filtered_symbols):
    print(f"filtered_symbol = {filtered_symbol}, i={i}")
    ast_object = convert_to_ast_object(filtered_symbol)
    print('ast_object = ', ast_object)
# Out:
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.agent.agent`/Agent#, scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.agent.agent, 1), Descriptor(Agent, 2))), i=0
# ast_object =  <ast.ClassDef object at 0x17995c6d0>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.agent.agent`/Agent#__init__()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.agent.agent, 1), Descriptor(Agent, 2), Descriptor(__init__, 4))), i=1
# ast_object =  <ast.FunctionDef object at 0x17995c7f0>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.agent.agent`/Agent#__iter__()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.agent.agent, 1), Descriptor(Agent, 2), Descriptor(__iter__, 4))), i=2
# ast_object =  <ast.FunctionDef object at 0x17995c7c0>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.agent.agent`/Agent#__next__()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.agent.agent, 1), Descriptor(Agent, 2), Descriptor(__next__, 4))), i=3
# ast_object =  <ast.FunctionDef object at 0x17995cd00>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.agent.agent`/Agent#run()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.agent.agent, 1), Descriptor(Agent, 2), Descriptor(run, 4))), i=4
# ast_object =  <ast.FunctionDef object at 0x17995f250>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.agent.agent`/Agent#set_database_provider()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.agent.agent, 1), Descriptor(Agent, 2), Descriptor(set_database_provider, 4))), i=5
# ast_object =  <ast.FunctionDef object at 0x17995f190>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.agent.agent`/AgentInstance#, scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.agent.agent, 1), Descriptor(AgentInstance, 2))), i=6
# ast_object =  <ast.ClassDef object at 0x1799643d0>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.agent.agent`/AgentInstance#Config#, scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.agent.agent, 1), Descriptor(AgentInstance, 2), Descriptor(Config, 2))), i=7
# ast_object =  <ast.ClassDef object at 0x179964550>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.agent.agent`/AgentInstance#create()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.agent.agent, 1), Descriptor(AgentInstance, 2), Descriptor(create, 4))), i=8
# ast_object =  <ast.FunctionDef object at 0x179964e20>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.agent.agent`/AgentInstance#run()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.agent.agent, 1), Descriptor(AgentInstance, 2), Descriptor(run, 4))), i=9
# ast_object =  <ast.FunctionDef object at 0x179964c40>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.agent.agent`/AgentToolkitBuilder#, scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.agent.agent, 1), Descriptor(AgentToolkitBuilder, 2))), i=10
# ast_object =  <ast.ClassDef object at 0x17995f970>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.agent.agent`/AgentToolkitBuilder#build()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.agent.agent, 1), Descriptor(AgentToolkitBuilder, 2), Descriptor(build, 4))), i=11
# ast_object =  <ast.FunctionDef object at 0x179964130>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.agent.agent`/AgentToolkitNames#, scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.agent.agent, 1), Descriptor(AgentToolkitNames, 2))), i=12
# ast_object =  <ast.ClassDef object at 0x17995c6a0>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.agent.error`/AgentDatabaseError#, scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.agent.error, 1), Descriptor(AgentDatabaseError, 2))), i=13
# ast_object =  <ast.ClassDef object at 0x1799745b0>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.agent.error`/AgentGeneralError#, scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.agent.error, 1), Descriptor(AgentGeneralError, 2))), i=14
# ast_object =  <ast.ClassDef object at 0x179974a60>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.agent.error`/AgentMaxIterError#, scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.agent.error, 1), Descriptor(AgentMaxIterError, 2))), i=15
# ast_object =  <ast.ClassDef object at 0x179974f10>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.agent.error`/AgentResultError#, scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.agent.error, 1), Descriptor(AgentResultError, 2))), i=16
# ast_object =  <ast.ClassDef object at 0x179974d30>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.agent.error`/AgentStopIteration#, scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.agent.error, 1), Descriptor(AgentStopIteration, 2))), i=17
# ast_object =  <ast.ClassDef object at 0x179974be0>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.agent.error`/AgentTaskGeneralError#, scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.agent.error, 1), Descriptor(AgentTaskGeneralError, 2))), i=18
# ast_object =  <ast.ClassDef object at 0x179974610>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.agent.error`/AgentTaskGitError#, scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.agent.error, 1), Descriptor(AgentTaskGitError, 2))), i=19
# ast_object =  <ast.ClassDef object at 0x1799744c0>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.agent.error`/AgentTaskInstructions#, scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.agent.error, 1), Descriptor(AgentTaskInstructions, 2))), i=20
# ast_object =  <ast.ClassDef object at 0x1799741c0>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.agent.error`/AgentTaskStateError#, scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.agent.error, 1), Descriptor(AgentTaskStateError, 2))), i=21
# ast_object =  <ast.ClassDef object at 0x179974700>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.agent.error`/UnknownToolError#, scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.agent.error, 1), Descriptor(UnknownToolError, 2))), i=22
# ast_object =  <ast.ClassDef object at 0x179974eb0>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.agent.error`/UnknownToolError#__init__()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.agent.error, 1), Descriptor(UnknownToolError, 2), Descriptor(__init__, 4))), i=23
# ast_object =  <ast.FunctionDef object at 0x179974b80>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.agent.instances`/OpenAIAutomataAgentInstance#, scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.agent.instances, 1), Descriptor(OpenAIAutomataAgentInstance, 2))), i=24
# ast_object =  <ast.ClassDef object at 0x179a93bb0>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.agent.instances`/OpenAIAutomataAgentInstance#Config#, scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.agent.instances, 1), Descriptor(OpenAIAutomataAgentInstance, 2), Descriptor(Config, 2))), i=25
# ast_object =  <ast.ClassDef object at 0x179a934c0>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.agent.instances`/OpenAIAutomataAgentInstance#run()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.agent.instances, 1), Descriptor(OpenAIAutomataAgentInstance, 2), Descriptor(run, 4))), i=26
# ast_object =  <ast.FunctionDef object at 0x179a93580>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.agent.providers`/OpenAIAgentToolkitBuilder#, scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.agent.providers, 1), Descriptor(OpenAIAgentToolkitBuilder, 2))), i=27
# ast_object =  <ast.ClassDef object at 0x1798e98b0>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.agent.providers`/OpenAIAgentToolkitBuilder#build_for_open_ai()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.agent.providers, 1), Descriptor(OpenAIAgentToolkitBuilder, 2), Descriptor(build_for_open_ai, 4))), i=28
# ast_object =  <ast.FunctionDef object at 0x1798e9df0>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.agent.providers`/OpenAIAgentToolkitBuilder#can_handle()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.agent.providers, 1), Descriptor(OpenAIAgentToolkitBuilder, 2), Descriptor(can_handle, 4))), i=29
# ast_object =  <ast.FunctionDef object at 0x1798ec100>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.agent.providers`/OpenAIAutomataAgent#, scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.agent.providers, 1), Descriptor(OpenAIAutomataAgent, 2))), i=30
# ast_object =  <ast.ClassDef object at 0x1798b49a0>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.agent.providers`/OpenAIAutomataAgent#__init__()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.agent.providers, 1), Descriptor(OpenAIAutomataAgent, 2), Descriptor(__init__, 4))), i=31
# ast_object =  <ast.FunctionDef object at 0x1798b80a0>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.agent.providers`/OpenAIAutomataAgent#__iter__()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.agent.providers, 1), Descriptor(OpenAIAutomataAgent, 2), Descriptor(__iter__, 4))), i=32
# ast_object =  <ast.FunctionDef object at 0x1798b87c0>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.agent.providers`/OpenAIAutomataAgent#__next__()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.agent.providers, 1), Descriptor(OpenAIAutomataAgent, 2), Descriptor(__next__, 4))), i=33
# ast_object =  <ast.FunctionDef object at 0x1798b8f40>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.agent.providers`/OpenAIAutomataAgent#_build_initial_messages()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.agent.providers, 1), Descriptor(OpenAIAutomataAgent, 2), Descriptor(_build_initial_messages, 4))), i=34
# ast_object =  <ast.FunctionDef object at 0x1798d1520>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.agent.providers`/OpenAIAutomataAgent#_get_next_user_response()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.agent.providers, 1), Descriptor(OpenAIAutomataAgent, 2), Descriptor(_get_next_user_response, 4))), i=35
# ast_object =  <ast.FunctionDef object at 0x1798d5e80>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.agent.providers`/OpenAIAutomataAgent#_get_termination_tool()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.agent.providers, 1), Descriptor(OpenAIAutomataAgent, 2), Descriptor(_get_termination_tool, 4))), i=36
# ast_object =  <ast.FunctionDef object at 0x1798e9100>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.agent.providers`/OpenAIAutomataAgent#functions()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.agent.providers, 1), Descriptor(OpenAIAutomataAgent, 2), Descriptor(functions, 4))), i=37
# ast_object =  <ast.FunctionDef object at 0x1798c5f40>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.agent.providers`/OpenAIAutomataAgent#run()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.agent.providers, 1), Descriptor(OpenAIAutomataAgent, 2), Descriptor(run, 4))), i=38
# ast_object =  <ast.FunctionDef object at 0x1798ca520>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.agent.providers`/OpenAIAutomataAgent#set_database_provider()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.agent.providers, 1), Descriptor(OpenAIAutomataAgent, 2), Descriptor(set_database_provider, 4))), i=39
# ast_object =  <ast.FunctionDef object at 0x1798cd520>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.agent.providers`/OpenAIAutomataAgent#terminate()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.agent.providers, 1), Descriptor(OpenAIAutomataAgent, 2), Descriptor(terminate, 4))), i=40
# ast_object =  <ast.FunctionDef object at 0x1798e9340>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.agent.providers`/OpenAIAutomataAgent#tools()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.agent.providers, 1), Descriptor(OpenAIAutomataAgent, 2), Descriptor(tools, 4))), i=41
# ast_object =  <ast.FunctionDef object at 0x1798c2fa0>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.cli.commands`/cli()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.cli.commands, 1), Descriptor(cli, 4))), i=42
# ast_object =  <ast.FunctionDef object at 0x1799094f0>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.cli.commands`/reconfigure_logging()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.cli.commands, 1), Descriptor(reconfigure_logging, 4))), i=43
# ast_object =  <ast.FunctionDef object at 0x17990e280>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.cli.commands`/run_agent()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.cli.commands, 1), Descriptor(run_agent, 4))), i=44
# ast_object =  <ast.FunctionDef object at 0x1798f55e0>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.cli.commands`/run_code_embedding()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.cli.commands, 1), Descriptor(run_code_embedding, 4))), i=45
# ast_object =  <ast.FunctionDef object at 0x179909370>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.cli.commands`/run_doc_embedding()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.cli.commands, 1), Descriptor(run_doc_embedding, 4))), i=46
# ast_object =  <ast.FunctionDef object at 0x179906760>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.cli.commands`/run_doc_post_process()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.cli.commands, 1), Descriptor(run_doc_post_process, 4))), i=47
# ast_object =  <ast.FunctionDef object at 0x1798f9df0>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.cli.options`/agent_options()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.cli.options, 1), Descriptor(agent_options, 4))), i=48
# ast_object =  <ast.FunctionDef object at 0x1798fd760>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.cli.options`/common_options()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.cli.options, 1), Descriptor(common_options, 4))), i=49
# ast_object =  <ast.FunctionDef object at 0x179901460>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.cli.scripts.run_agent`/main()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.cli.scripts.run_agent, 1), Descriptor(main, 4))), i=50
# ast_object =  <ast.FunctionDef object at 0x179925850>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.cli.scripts.run_agent`/process_issues()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.cli.scripts.run_agent, 1), Descriptor(process_issues, 4))), i=51
# ast_object =  <ast.FunctionDef object at 0x17992ac40>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.cli.scripts.run_agent_config_validation`/test_yaml_compatibility()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.cli.scripts.run_agent_config_validation, 1), Descriptor(test_yaml_compatibility, 4))), i=52
# ast_object =  <ast.FunctionDef object at 0x179947250>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.cli.scripts.run_agent_config_validation`/test_yaml_validation()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.cli.scripts.run_agent_config_validation, 1), Descriptor(test_yaml_validation, 4))), i=53
# ast_object =  <ast.FunctionDef object at 0x179947fa0>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.cli.scripts.run_code_embedding`/main()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.cli.scripts.run_code_embedding, 1), Descriptor(main, 4))), i=54
# ast_object =  <ast.FunctionDef object at 0x179ef75e0>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.cli.scripts.run_doc_embedding`/initialize_providers()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.cli.scripts.run_doc_embedding, 1), Descriptor(initialize_providers, 4))), i=55
# ast_object =  <ast.FunctionDef object at 0x1798a7d00>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.cli.scripts.run_doc_embedding`/main()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.cli.scripts.run_doc_embedding, 1), Descriptor(main, 4))), i=56
# ast_object =  <ast.FunctionDef object at 0x17996c970>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.cli.scripts.run_doc_post_process`/main()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.cli.scripts.run_doc_post_process, 1), Descriptor(main, 4))), i=57
# ast_object =  <ast.FunctionDef object at 0x179916610>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.config.base`/AgentConfig#, scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.config.base, 1), Descriptor(AgentConfig, 2))), i=58
# ast_object =  <ast.ClassDef object at 0x17984f6a0>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.config.base`/AgentConfig#Config#, scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.config.base, 1), Descriptor(AgentConfig, 2), Descriptor(Config, 2))), i=59
# ast_object =  <ast.ClassDef object at 0x1798558e0>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.config.base`/AgentConfig#_load_automata_yaml_config()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.config.base, 1), Descriptor(AgentConfig, 2), Descriptor(_load_automata_yaml_config, 4))), i=60
# ast_object =  <ast.FunctionDef object at 0x17987e070>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.config.base`/AgentConfig#get_llm_provider()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.config.base, 1), Descriptor(AgentConfig, 2), Descriptor(get_llm_provider, 4))), i=61
# ast_object =  <ast.FunctionDef object at 0x17987e1c0>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.config.base`/AgentConfig#load()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.config.base, 1), Descriptor(AgentConfig, 2), Descriptor(load, 4))), i=62
# ast_object =  <ast.FunctionDef object at 0x179855d90>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.config.base`/AgentConfigBuilder#, scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.config.base, 1), Descriptor(AgentConfigBuilder, 2))), i=63
# ast_object =  <ast.ClassDef object at 0x17987b250>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.config.base`/AgentConfigBuilder#__init__()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.config.base, 1), Descriptor(AgentConfigBuilder, 2), Descriptor(__init__, 4))), i=64
# ast_object =  <ast.FunctionDef object at 0x17987b460>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.config.base`/AgentConfigBuilder#_validate_type()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.config.base, 1), Descriptor(AgentConfigBuilder, 2), Descriptor(_validate_type, 4))), i=65
# ast_object =  <ast.FunctionDef object at 0x17988f7f0>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.config.base`/AgentConfigBuilder#build()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.config.base, 1), Descriptor(AgentConfigBuilder, 2), Descriptor(build, 4))), i=66
# ast_object =  <ast.FunctionDef object at 0x17987ba30>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.config.base`/AgentConfigBuilder#create_config()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.config.base, 1), Descriptor(AgentConfigBuilder, 2), Descriptor(create_config, 4))), i=67
# ast_object =  <ast.FunctionDef object at 0x17987beb0>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.config.base`/AgentConfigBuilder#from_config()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.config.base, 1), Descriptor(AgentConfigBuilder, 2), Descriptor(from_config, 4))), i=68
# ast_object =  <ast.FunctionDef object at 0x1798844c0>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.config.base`/AgentConfigBuilder#from_name()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.config.base, 1), Descriptor(AgentConfigBuilder, 2), Descriptor(from_name, 4))), i=69
# ast_object =  <ast.FunctionDef object at 0x17986db20>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.config.base`/AgentConfigBuilder#with_max_iterations()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.config.base, 1), Descriptor(AgentConfigBuilder, 2), Descriptor(with_max_iterations, 4))), i=70
# ast_object =  <ast.FunctionDef object at 0x179889580>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.config.base`/AgentConfigBuilder#with_model()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.config.base, 1), Descriptor(AgentConfigBuilder, 2), Descriptor(with_model, 4))), i=71
# ast_object =  <ast.FunctionDef object at 0x17986f250>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.config.base`/AgentConfigBuilder#with_session_id()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.config.base, 1), Descriptor(AgentConfigBuilder, 2), Descriptor(with_session_id, 4))), i=72
# ast_object =  <ast.FunctionDef object at 0x1798843d0>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.config.base`/AgentConfigBuilder#with_stream()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.config.base, 1), Descriptor(AgentConfigBuilder, 2), Descriptor(with_stream, 4))), i=73
# ast_object =  <ast.FunctionDef object at 0x17986f8e0>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.config.base`/AgentConfigBuilder#with_temperature()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.config.base, 1), Descriptor(AgentConfigBuilder, 2), Descriptor(with_temperature, 4))), i=74
# ast_object =  <ast.FunctionDef object at 0x179889d60>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.config.base`/AgentConfigBuilder#with_tools()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.config.base, 1), Descriptor(AgentConfigBuilder, 2), Descriptor(with_tools, 4))), i=75
# ast_object =  <ast.FunctionDef object at 0x17986f460>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.config.base`/AgentConfigBuilder#with_verbose()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.config.base, 1), Descriptor(AgentConfigBuilder, 2), Descriptor(with_verbose, 4))), i=76
# ast_object =  <ast.FunctionDef object at 0x17986fb80>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.config.base`/AgentConfigName#, scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.config.base, 1), Descriptor(AgentConfigName, 2))), i=77
# ast_object =  <ast.ClassDef object at 0x17984f8e0>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.config.base`/ConfigCategory#, scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.config.base, 1), Descriptor(ConfigCategory, 2))), i=78
# ast_object =  <ast.ClassDef object at 0x179851f10>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.config.base`/EmbeddingDataCategory#, scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.config.base, 1), Descriptor(EmbeddingDataCategory, 2))), i=79
# ast_object =  <ast.ClassDef object at 0x179851a00>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.config.base`/InstructionConfigVersion#, scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.config.base, 1), Descriptor(InstructionConfigVersion, 2))), i=80
# ast_object =  <ast.ClassDef object at 0x17984f4f0>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.config.base`/LLMProvider#, scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.config.base, 1), Descriptor(LLMProvider, 2))), i=81
# ast_object =  <ast.ClassDef object at 0x17984fbb0>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.config.base`/PathEnum#, scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.config.base, 1), Descriptor(PathEnum, 2))), i=82
# ast_object =  <ast.ClassDef object at 0x179851760>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.config.base`/PathEnum#to_path()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.config.base, 1), Descriptor(PathEnum, 2), Descriptor(to_path, 4))), i=83
# ast_object =  <ast.FunctionDef object at 0x179851310>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.config.openai_agent`/OpenAIAutomataAgentConfig#, scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.config.openai_agent, 1), Descriptor(OpenAIAutomataAgentConfig, 2))), i=84
# ast_object =  <ast.ClassDef object at 0x17991e8e0>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.config.openai_agent`/OpenAIAutomataAgentConfig#Config#, scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.config.openai_agent, 1), Descriptor(OpenAIAutomataAgentConfig, 2), Descriptor(Config, 2))), i=85
# ast_object =  <ast.ClassDef object at 0x17991e7f0>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.config.openai_agent`/OpenAIAutomataAgentConfig#TemplateFormatter#, scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.config.openai_agent, 1), Descriptor(OpenAIAutomataAgentConfig, 2), Descriptor(TemplateFormatter, 2))), i=86
# ast_object =  <ast.ClassDef object at 0x179f7dfd0>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.config.openai_agent`/OpenAIAutomataAgentConfig#TemplateFormatter#create_default_formatter()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.config.openai_agent, 1), Descriptor(OpenAIAutomataAgentConfig, 2), Descriptor(TemplateFormatter, 2), Descriptor(create_default_formatter, 4))), i=87
# ast_object =  <ast.FunctionDef object at 0x179f7dfa0>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.config.openai_agent`/OpenAIAutomataAgentConfig#_formatted_instruction()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.config.openai_agent, 1), Descriptor(OpenAIAutomataAgentConfig, 2), Descriptor(_formatted_instruction, 4))), i=88
# ast_object =  <ast.FunctionDef object at 0x17984b640>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.config.openai_agent`/OpenAIAutomataAgentConfig#get_llm_provider()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.config.openai_agent, 1), Descriptor(OpenAIAutomataAgentConfig, 2), Descriptor(get_llm_provider, 4))), i=89
# ast_object =  <ast.FunctionDef object at 0x17984b340>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.config.openai_agent`/OpenAIAutomataAgentConfig#load()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.config.openai_agent, 1), Descriptor(OpenAIAutomataAgentConfig, 2), Descriptor(load, 4))), i=90
# ast_object =  <ast.FunctionDef object at 0x17992e310>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.config.openai_agent`/OpenAIAutomataAgentConfigBuilder#, scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.config.openai_agent, 1), Descriptor(OpenAIAutomataAgentConfigBuilder, 2))), i=91
# ast_object =  <ast.ClassDef object at 0x17984c880>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.config.openai_agent`/OpenAIAutomataAgentConfigBuilder#create_config()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.config.openai_agent, 1), Descriptor(OpenAIAutomataAgentConfigBuilder, 2), Descriptor(create_config, 4))), i=92
# ast_object =  <ast.FunctionDef object at 0x17984cb50>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.config.openai_agent`/OpenAIAutomataAgentConfigBuilder#create_from_args()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.config.openai_agent, 1), Descriptor(OpenAIAutomataAgentConfigBuilder, 2), Descriptor(create_from_args, 4))), i=93
# ast_object =  <ast.FunctionDef object at 0x1798f52e0>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.config.openai_agent`/OpenAIAutomataAgentConfigBuilder#with_instruction_version()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.config.openai_agent, 1), Descriptor(OpenAIAutomataAgentConfigBuilder, 2), Descriptor(with_instruction_version, 4))), i=94
# ast_object =  <ast.FunctionDef object at 0x1798f1e80>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.config.openai_agent`/OpenAIAutomataAgentConfigBuilder#with_model()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.config.openai_agent, 1), Descriptor(OpenAIAutomataAgentConfigBuilder, 2), Descriptor(with_model, 4))), i=95
# ast_object =  <ast.FunctionDef object at 0x1798580a0>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.config.openai_agent`/OpenAIAutomataAgentConfigBuilder#with_system_template_formatter()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.config.openai_agent, 1), Descriptor(OpenAIAutomataAgentConfigBuilder, 2), Descriptor(with_system_template_formatter, 4))), i=96
# ast_object =  <ast.FunctionDef object at 0x179858a90>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.context_providers.symbol_synchronization`/SymbolProviderRegistry#, scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.context_providers.symbol_synchronization, 1), Descriptor(SymbolProviderRegistry, 2))), i=97
# ast_object =  <ast.ClassDef object at 0x17986d070>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.context_providers.symbol_synchronization`/SymbolProviderRegistry#get_sorted_supported_symbols()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.context_providers.symbol_synchronization, 1), Descriptor(SymbolProviderRegistry, 2), Descriptor(get_sorted_supported_symbols, 4))), i=98
# ast_object =  <ast.FunctionDef object at 0x179861640>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.context_providers.symbol_synchronization`/SymbolProviderRegistry#register_provider()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.context_providers.symbol_synchronization, 1), Descriptor(SymbolProviderRegistry, 2), Descriptor(register_provider, 4))), i=99
# ast_object =  <ast.FunctionDef object at 0x17986c940>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.context_providers.symbol_synchronization`/SymbolProviderRegistry#synchronize()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.context_providers.symbol_synchronization, 1), Descriptor(SymbolProviderRegistry, 2), Descriptor(synchronize, 4))), i=100
# ast_object =  <ast.FunctionDef object at 0x17986c460>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.context_providers.symbol_synchronization`/SymbolProviderSynchronizationContext#, scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.context_providers.symbol_synchronization, 1), Descriptor(SymbolProviderSynchronizationContext, 2))), i=101
# ast_object =  <ast.ClassDef object at 0x1798639a0>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.context_providers.symbol_synchronization`/SymbolProviderSynchronizationContext#__enter__()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.context_providers.symbol_synchronization, 1), Descriptor(SymbolProviderSynchronizationContext, 2), Descriptor(__enter__, 4))), i=102
# ast_object =  <ast.FunctionDef object at 0x179863760>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.context_providers.symbol_synchronization`/SymbolProviderSynchronizationContext#__exit__()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.context_providers.symbol_synchronization, 1), Descriptor(SymbolProviderSynchronizationContext, 2), Descriptor(__exit__, 4))), i=103
# ast_object =  <ast.FunctionDef object at 0x179863130>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.context_providers.symbol_synchronization`/SymbolProviderSynchronizationContext#__init__()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.context_providers.symbol_synchronization, 1), Descriptor(SymbolProviderSynchronizationContext, 2), Descriptor(__init__, 4))), i=104
# ast_object =  <ast.FunctionDef object at 0x179863850>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.context_providers.symbol_synchronization`/SymbolProviderSynchronizationContext#register_provider()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.context_providers.symbol_synchronization, 1), Descriptor(SymbolProviderSynchronizationContext, 2), Descriptor(register_provider, 4))), i=105
# ast_object =  <ast.FunctionDef object at 0x1798630a0>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.context_providers.symbol_synchronization`/SymbolProviderSynchronizationContext#synchronize()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.context_providers.symbol_synchronization, 1), Descriptor(SymbolProviderSynchronizationContext, 2), Descriptor(synchronize, 4))), i=106
# ast_object =  <ast.FunctionDef object at 0x179868dc0>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.core.base.database.relational`/RelationalDatabase#, scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.core.base.database.relational, 1), Descriptor(RelationalDatabase, 2))), i=107
# ast_object =  <ast.ClassDef object at 0x1798e26a0>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.core.base.database.relational`/RelationalDatabase#close()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.core.base.database.relational, 1), Descriptor(RelationalDatabase, 2), Descriptor(close, 4))), i=108
# ast_object =  <ast.FunctionDef object at 0x1798e23a0>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.core.base.database.relational`/RelationalDatabase#connect()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.core.base.database.relational, 1), Descriptor(RelationalDatabase, 2), Descriptor(connect, 4))), i=109
# ast_object =  <ast.FunctionDef object at 0x1798e25b0>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.core.base.database.relational`/RelationalDatabase#create_table()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.core.base.database.relational, 1), Descriptor(RelationalDatabase, 2), Descriptor(create_table, 4))), i=110
# ast_object =  <ast.FunctionDef object at 0x1798e21f0>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.core.base.database.relational`/RelationalDatabase#delete()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.core.base.database.relational, 1), Descriptor(RelationalDatabase, 2), Descriptor(delete, 4))), i=111
# ast_object =  <ast.FunctionDef object at 0x17990b2b0>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.core.base.database.relational`/RelationalDatabase#insert()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.core.base.database.relational, 1), Descriptor(RelationalDatabase, 2), Descriptor(insert, 4))), i=112
# ast_object =  <ast.FunctionDef object at 0x1798fcf40>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.core.base.database.relational`/RelationalDatabase#select()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.core.base.database.relational, 1), Descriptor(RelationalDatabase, 2), Descriptor(select, 4))), i=113
# ast_object =  <ast.FunctionDef object at 0x1798fccd0>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.core.base.database.relational`/RelationalDatabase#update_entry()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.core.base.database.relational, 1), Descriptor(RelationalDatabase, 2), Descriptor(update_entry, 4))), i=114
# ast_object =  <ast.FunctionDef object at 0x1798fca00>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.core.base.database.relational`/SQLDatabase#, scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.core.base.database.relational, 1), Descriptor(SQLDatabase, 2))), i=115
# ast_object =  <ast.ClassDef object at 0x17990b040>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.core.base.database.relational`/SQLDatabase#close()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.core.base.database.relational, 1), Descriptor(SQLDatabase, 2), Descriptor(close, 4))), i=116
# ast_object =  <ast.FunctionDef object at 0x1798b0580>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.core.base.database.relational`/SQLDatabase#connect()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.core.base.database.relational, 1), Descriptor(SQLDatabase, 2), Descriptor(connect, 4))), i=117
# ast_object =  <ast.FunctionDef object at 0x17990ee50>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.core.base.database.relational`/SQLDatabase#create_table()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.core.base.database.relational, 1), Descriptor(SQLDatabase, 2), Descriptor(create_table, 4))), i=118
# ast_object =  <ast.FunctionDef object at 0x1798ab520>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.core.base.database.relational`/SQLDatabase#delete()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.core.base.database.relational, 1), Descriptor(SQLDatabase, 2), Descriptor(delete, 4))), i=119
# ast_object =  <ast.FunctionDef object at 0x179868a30>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.core.base.database.relational`/SQLDatabase#insert()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.core.base.database.relational, 1), Descriptor(SQLDatabase, 2), Descriptor(insert, 4))), i=120
# ast_object =  <ast.FunctionDef object at 0x17989f100>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.core.base.database.relational`/SQLDatabase#select()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.core.base.database.relational, 1), Descriptor(SQLDatabase, 2), Descriptor(select, 4))), i=121
# ast_object =  <ast.FunctionDef object at 0x17989bf40>
# ...
# ast_object =  <ast.FunctionDef object at 0x179bd61c0>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.tasks.environment`/AutomataTaskEnvironment#reset()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.tasks.environment, 1), Descriptor(AutomataTaskEnvironment, 2), Descriptor(reset, 4))), i=607
# ast_object =  <ast.FunctionDef object at 0x179bdc790>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.tasks.environment`/AutomataTaskEnvironment#teardown()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.tasks.environment, 1), Descriptor(AutomataTaskEnvironment, 2), Descriptor(teardown, 4))), i=608
# ast_object =  <ast.FunctionDef object at 0x179c4b130>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.tasks.environment`/AutomataTaskEnvironment#validate()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.tasks.environment, 1), Descriptor(AutomataTaskEnvironment, 2), Descriptor(validate, 4))), i=609
# ast_object =  <ast.FunctionDef object at 0x179dc05e0>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.tasks.executor`/AutomataTaskExecutor#, scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.tasks.executor, 1), Descriptor(AutomataTaskExecutor, 2))), i=610
# ast_object =  <ast.ClassDef object at 0x179c43970>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.tasks.executor`/AutomataTaskExecutor#__init__()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.tasks.executor, 1), Descriptor(AutomataTaskExecutor, 2), Descriptor(__init__, 4))), i=611
# ast_object =  <ast.FunctionDef object at 0x179c438b0>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.tasks.executor`/AutomataTaskExecutor#_exponential_backoff()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.tasks.executor, 1), Descriptor(AutomataTaskExecutor, 2), Descriptor(_exponential_backoff, 4))), i=612
# ast_object =  <ast.FunctionDef object at 0x179c31d00>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.tasks.executor`/AutomataTaskExecutor#execute()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.tasks.executor, 1), Descriptor(AutomataTaskExecutor, 2), Descriptor(execute, 4))), i=613
# ast_object =  <ast.FunctionDef object at 0x179c436d0>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.tasks.executor`/IAutomataTaskExecution#, scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.tasks.executor, 1), Descriptor(IAutomataTaskExecution, 2))), i=614
# ast_object =  <ast.ClassDef object at 0x179c2eee0>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.tasks.executor`/IAutomataTaskExecution#_build_agent()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.tasks.executor, 1), Descriptor(IAutomataTaskExecution, 2), Descriptor(_build_agent, 4))), i=615
# ast_object =  <ast.FunctionDef object at 0x179c3e5b0>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.tasks.executor`/IAutomataTaskExecution#execute()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.tasks.executor, 1), Descriptor(IAutomataTaskExecution, 2), Descriptor(execute, 4))), i=616
# ast_object =  <ast.FunctionDef object at 0x179c2ebb0>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.tasks.tasks`/AutomataTask#, scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.tasks.tasks, 1), Descriptor(AutomataTask, 2))), i=617
# ast_object =  <ast.ClassDef object at 0x179ae9610>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.tasks.tasks`/AutomataTask#__init__()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.tasks.tasks, 1), Descriptor(AutomataTask, 2), Descriptor(__init__, 4))), i=618
# ast_object =  <ast.FunctionDef object at 0x179ae95b0>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.tasks.tasks`/AutomataTask#get_logs()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.tasks.tasks, 1), Descriptor(AutomataTask, 2), Descriptor(get_logs, 4))), i=619
# ast_object =  <ast.FunctionDef object at 0x179c33970>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.tasks.tasks`/AutomataTask#initialize_logging()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.tasks.tasks, 1), Descriptor(AutomataTask, 2), Descriptor(initialize_logging, 4))), i=620
# ast_object =  <ast.FunctionDef object at 0x179c32250>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.tools.base`/Tool#, scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.tools.base, 1), Descriptor(Tool, 2))), i=621
# ast_object =  <ast.ClassDef object at 0x179ae9fa0>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.tools.base`/Tool#Config#, scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.tools.base, 1), Descriptor(Tool, 2), Descriptor(Config, 2))), i=622
# ast_object =  <ast.ClassDef object at 0x179ae9cd0>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.tools.base`/Tool#run()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.tools.base, 1), Descriptor(Tool, 2), Descriptor(run, 4))), i=623
# ast_object =  <ast.FunctionDef object at 0x179c31a30>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.tools.builders.context_oracle`/ContextOracleOpenAIToolkitBuilder#, scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.tools.builders.context_oracle, 1), Descriptor(ContextOracleOpenAIToolkitBuilder, 2))), i=624
# ast_object =  <ast.ClassDef object at 0x179ad3d90>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.tools.builders.context_oracle`/ContextOracleOpenAIToolkitBuilder#build_for_open_ai()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.tools.builders.context_oracle, 1), Descriptor(ContextOracleOpenAIToolkitBuilder, 2), Descriptor(build_for_open_ai, 4))), i=625
# ast_object =  <ast.FunctionDef object at 0x179ad3b80>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.tools.builders.context_oracle`/ContextOracleToolkitBuilder#, scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.tools.builders.context_oracle, 1), Descriptor(ContextOracleToolkitBuilder, 2))), i=626
# ast_object =  <ast.ClassDef object at 0x179aba430>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.tools.builders.context_oracle`/ContextOracleToolkitBuilder#__init__()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.tools.builders.context_oracle, 1), Descriptor(ContextOracleToolkitBuilder, 2), Descriptor(__init__, 4))), i=627
# ast_object =  <ast.FunctionDef object at 0x179aba340>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.tools.builders.context_oracle`/ContextOracleToolkitBuilder#_get_context()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.tools.builders.context_oracle, 1), Descriptor(ContextOracleToolkitBuilder, 2), Descriptor(_get_context, 4))), i=628
# ast_object =  <ast.FunctionDef object at 0x179ac4970>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.tools.builders.context_oracle`/ContextOracleToolkitBuilder#build()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.tools.builders.context_oracle, 1), Descriptor(ContextOracleToolkitBuilder, 2), Descriptor(build, 4))), i=629
# ast_object =  <ast.FunctionDef object at 0x179ac6d60>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.tools.builders.symbol_search`/SearchTool#, scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.tools.builders.symbol_search, 1), Descriptor(SearchTool, 2))), i=630
# ast_object =  <ast.ClassDef object at 0x179ad7b20>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.tools.builders.symbol_search`/SymbolSearchOpenAIToolkitBuilder#, scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.tools.builders.symbol_search, 1), Descriptor(SymbolSearchOpenAIToolkitBuilder, 2))), i=631
# ast_object =  <ast.ClassDef object at 0x179ad3790>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.tools.builders.symbol_search`/SymbolSearchOpenAIToolkitBuilder#build_for_open_ai()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.tools.builders.symbol_search, 1), Descriptor(SymbolSearchOpenAIToolkitBuilder, 2), Descriptor(build_for_open_ai, 4))), i=632
# ast_object =  <ast.FunctionDef object at 0x179c33790>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.tools.builders.symbol_search`/SymbolSearchToolkitBuilder#, scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.tools.builders.symbol_search, 1), Descriptor(SymbolSearchToolkitBuilder, 2))), i=633
# ast_object =  <ast.ClassDef object at 0x179ad77c0>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.tools.builders.symbol_search`/SymbolSearchToolkitBuilder#__init__()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.tools.builders.symbol_search, 1), Descriptor(SymbolSearchToolkitBuilder, 2), Descriptor(__init__, 4))), i=634
# ast_object =  <ast.FunctionDef object at 0x179ad76d0>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.tools.builders.symbol_search`/SymbolSearchToolkitBuilder#_exact_search_processor()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.tools.builders.symbol_search, 1), Descriptor(SymbolSearchToolkitBuilder, 2), Descriptor(_exact_search_processor, 4))), i=635
# ast_object =  <ast.FunctionDef object at 0x179ac8c10>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.tools.builders.symbol_search`/SymbolSearchToolkitBuilder#_retrieve_source_code_by_symbol_processor()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.tools.builders.symbol_search, 1), Descriptor(SymbolSearchToolkitBuilder, 2), Descriptor(_retrieve_source_code_by_symbol_processor, 4))), i=636
# ast_object =  <ast.FunctionDef object at 0x179ac4280>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.tools.builders.symbol_search`/SymbolSearchToolkitBuilder#_symbol_rank_search_processor()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.tools.builders.symbol_search, 1), Descriptor(SymbolSearchToolkitBuilder, 2), Descriptor(_symbol_rank_search_processor, 4))), i=637
# ast_object =  <ast.FunctionDef object at 0x179abaeb0>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.tools.builders.symbol_search`/SymbolSearchToolkitBuilder#_symbol_symbol_references_processor()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.tools.builders.symbol_search, 1), Descriptor(SymbolSearchToolkitBuilder, 2), Descriptor(_symbol_symbol_references_processor, 4))), i=638
# ast_object =  <ast.FunctionDef object at 0x179ac63d0>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.tools.builders.symbol_search`/SymbolSearchToolkitBuilder#build()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.tools.builders.symbol_search, 1), Descriptor(SymbolSearchToolkitBuilder, 2), Descriptor(build, 4))), i=639
# ast_object =  <ast.FunctionDef object at 0x179aacfa0>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.tools.builders.symbol_search`/SymbolSearchToolkitBuilder#build_tool()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.tools.builders.symbol_search, 1), Descriptor(SymbolSearchToolkitBuilder, 2), Descriptor(build_tool, 4))), i=640
# ast_object =  <ast.FunctionDef object at 0x179ae5d30>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.tools.builders.symbol_search`/SymbolSearchToolkitBuilder#process_query()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.tools.builders.symbol_search, 1), Descriptor(SymbolSearchToolkitBuilder, 2), Descriptor(process_query, 4))), i=641
# ast_object =  <ast.FunctionDef object at 0x179aac460>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.tools.factory`/AgentToolFactory#, scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.tools.factory, 1), Descriptor(AgentToolFactory, 2))), i=642
# ast_object =  <ast.ClassDef object at 0x179a4ae80>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.tools.factory`/AgentToolFactory#build_tools()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.tools.factory, 1), Descriptor(AgentToolFactory, 2), Descriptor(build_tools, 4))), i=643
# ast_object =  <ast.FunctionDef object at 0x179aafa60>
# filtered_symbol = Symbol(scip-python python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260 `automata.tools.factory`/AgentToolFactory#create_tools_from_builder()., scip-python, Package(python automata 6e304eca4cda41fbac2bcc8445ed191a85e8b260), (Descriptor(automata.tools.factory, 1), Descriptor(AgentToolFactory, 2), Descriptor(create_tools_from_builder, 4))), i=644
# ast_object =  <ast.FunctionDef object at 0x179a58b50>

# %%
search = dependency_factory.get("symbol_search")
# Out:
# self.overrides.get("disable_synchronization", False) =  False
# provider =  <automata.memory_store.symbol_code_embedding.SymbolCodeEmbeddingHandler object at 0x179a58550>
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~/AutomataNoCruft/automata/singletons/dependency_factory.py:155, in DependencyFactory._synchronize_provider(self, provider)
#     154 synchronization_context.register_provider(provider)
# --> 155 synchronization_context.synchronize()
#
# File ~/AutomataNoCruft/automata/context_providers/symbol_synchronization.py:69, in SymbolProviderSynchronizationContext.synchronize(self)
#      68 def synchronize(self):
# ---> 69     SymbolProviderRegistry.synchronize()
#      70     self._was_synchronized = True
#
# File ~/AutomataNoCruft/automata/context_providers/symbol_synchronization.py:40, in SymbolProviderRegistry.synchronize()
#      39 if not SymbolProviderRegistry.sorted_supported_symbols:
# ---> 40     raise RuntimeError("No symbols are supported by any symbol provider")
#
# RuntimeError: No symbols are supported by any symbol provider
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 search = dependency_factory.get("symbol_search")
#
# File ~/AutomataNoCruft/automata/singletons/dependency_factory.py:110, in DependencyFactory.get(self, dependency)
#     108     creation_method = getattr(self, method_name)
#     109     logger.info(f"Creating dependency {dependency}")
# --> 110     instance = creation_method()
#     111 else:
#     112     raise AgentGeneralError(f"Dependency {dependency} not found.")
#
# File ~/AutomataNoCruft/automata/singletons/dependency_factory.py:247, in DependencyFactory.create_symbol_search(self)
#     243 symbol_graph: SymbolGraph = self.get("symbol_graph")
#     244 symbol_rank_config: SymbolRankConfig = self.overrides.get(
#     245     "symbol_rank_config", SymbolRankConfig()
#     246 )
# --> 247 symbol_code_embedding_handler: SymbolCodeEmbeddingBuilder = self.get(
#     248     "symbol_code_embedding_handler"
#     249 )
#     250 embedding_similarity_calculator: EmbeddingSimilarityCalculator = self.get(
#     251     "embedding_similarity_calculator"
#     252 )
#     253 return SymbolSearch(
#     254     symbol_graph,
#     255     symbol_rank_config,
#    (...)
#     258     embedding_similarity_calculator,
#     259 )
#
# File ~/AutomataNoCruft/automata/singletons/dependency_factory.py:118, in DependencyFactory.get(self, dependency)
#     116 # Perform synchronization
#     117 if isinstance(instance, ISymbolProvider):
# --> 118     self._synchronize_provider(instance)
#     120 return instance
#
# File ~/AutomataNoCruft/automata/singletons/dependency_factory.py:155, in DependencyFactory._synchronize_provider(self, provider)
#     153 print("provider = ", provider)
#     154 synchronization_context.register_provider(provider)
# --> 155 synchronization_context.synchronize()
#
# File ~/AutomataNoCruft/automata/context_providers/symbol_synchronization.py:62, in SymbolProviderSynchronizationContext.__exit__(self, type, value, traceback)
#      60 def __exit__(self, type, value, traceback):
#      61     if not self._was_synchronized:
# ---> 62         raise RuntimeError("Must synchronize symbol providers in synchronization context")
#
# RuntimeError: Must synchronize symbol providers in synchronization context

# %%
symbol_code_embedding_handler = dependency_factory.get('symbol_code_embedding_handler')

# %%
len(symbol_code_embedding_handler.get_sorted_supported_symbols())

# %%
search.symbol_rank_config = SymbolRankConfig(alpha=0.85)
search.z_score_power = 10
query = "How do I build a storage context?"
symbol_rank_search_results = search.symbol_rank_search(query)
print("Demonstrating SymbolRank results for query = `how do I index data?`\n")
for i,rank in enumerate(symbol_rank_search_results[0:10]):
    print(f"rank {i} = {rank[0].dotpath} with rank {rank[1]:.3f}")

# %%
embedding_similarity_calculator = dependency_factory.get('embedding_similarity_calculator')
code_embeddings = symbol_code_embedding_handler.get_ordered_entries()

print(f"Demonstrating code embedding search results for query = `{query}`\n")
code_similarity_results = embedding_similarity_calculator.calculate_query_similarity_dict(code_embeddings, query)
for i,rank in enumerate(list(code_similarity_results.items())[0:10]):
    print(f"rank {i} = {rank[0].dotpath} with distance {rank[1]:.3f}")
