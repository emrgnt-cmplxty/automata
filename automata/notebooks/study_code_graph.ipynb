# %%
import matplotlib.pyplot as plt
import json
import os
import pandas as pd
import seaborn as sns

from automata.configs.config_enums import ConfigCategory
from automata.tools.search.symbol_converter import SymbolConverter
from automata.tools.search.symbol_graph import SymbolGraph
from automata.tools.search.symbol_rank.symbol_embedding_map import SymbolEmbeddingMap
from automata.tools.search.symbol_rank.symbol_similarity import SymbolSimilarity

# %%
file_dir = os.getcwd()

scip_path = os.path.join(
    file_dir, "..", "configs", ConfigCategory.SYMBOLS.value, "index.scip"
)
embedding_path = os.path.join(
    file_dir, "..", "configs", ConfigCategory.SYMBOLS.value, "symbol_embedding.json"
)

# %%
symbol_converter = SymbolConverter()
symbol_graph = SymbolGraph(scip_path, symbol_converter)
symbol_subgraph = symbol_graph.symbol_to_symbol_subgraph
# Out:
#   2%|███▊                                                                                                                                                                       | 48/2150 [00:00<00:18, 112.04it/s]
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.cli.click_commands`/get_conversation().: Symbol Symbol(scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.cli.click_commands`/get_conversation()., scip-python, Package(python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43), (Descriptor(automata.cli.click_commands, 1), Descriptor(get_conversation, 4))) not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.cli.click_commands`/get_conversation().(ctx): Symbol Symbol(scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.cli.click_commands`/get_conversation().(ctx), scip-python, Package(python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43), (Descriptor(automata.cli.click_commands, 1), Descriptor(get_conversation, 4), Descriptor(ctx, 6))) not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.cli.click_commands`/get_conversation().(args): Symbol Symbol(scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.cli.click_commands`/get_conversation().(args), scip-python, Package(python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43), (Descriptor(automata.cli.click_commands, 1), Descriptor(get_conversation, 4), Descriptor(args, 6))) not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.cli.click_commands`/get_conversation().(kwargs): Symbol Symbol(scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.cli.click_commands`/get_conversation().(kwargs), scip-python, Package(python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43), (Descriptor(automata.cli.click_commands, 1), Descriptor(get_conversation, 4), Descriptor(kwargs, 6))) not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.cli.click_commands`/evaluator().: Symbol Symbol(scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.cli.click_commands`/evaluator()., scip-python, Package(python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43), (Descriptor(automata.cli.click_commands, 1), Descriptor(evaluator, 4))) not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.cli.click_commands`/evaluator().(ctx): Symbol Symbol(scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.cli.click_commands`/evaluator().(ctx), scip-python, Package(python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43), (Descriptor(automata.cli.click_commands, 1), Descriptor(evaluator, 4), Descriptor(ctx, 6))) not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.cli.click_commands`/evaluator().(args): Symbol Symbol(scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.cli.click_commands`/evaluator().(args), scip-python, Package(python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43), (Descriptor(automata.cli.click_commands, 1), Descriptor(evaluator, 4), Descriptor(args, 6))) not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.cli.click_commands`/evaluator().(kwargs): Symbol Symbol(scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.cli.click_commands`/evaluator().(kwargs), scip-python, Package(python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43), (Descriptor(automata.cli.click_commands, 1), Descriptor(evaluator, 4), Descriptor(kwargs, 6))) not found
#  12%|███████████████████▉                                                                                                                                                       | 251/2150 [00:09<00:35, 53.54it/s]
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.utils`/Namespace#: Symbol Symbol(scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.utils`/Namespace#, scip-python, Package(python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43), (Descriptor(automata.core.utils, 1), Descriptor(Namespace, 2))) not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.utils`/Namespace#__init__().: Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.utils`/Namespace#__init__().(self): Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.utils`/Namespace#__init__().(kwargs): Method descriptor found without module or class descriptor
#  26%|████████████████████████████████████████████▊                                                                                                                             | 566/2150 [00:26<00:07, 223.21it/s]
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.agent.tests.conftest`/__init__:: Module descriptor automata.core.agent.tests.conftest not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.agent.tests.conftest`/automata_agent().: Module descriptor automata.core.agent.tests.conftest not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.agent.tests.conftest`/automata_agent_config_builder().: Module descriptor automata.core.agent.tests.conftest not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.agent.tests.conftest`/automata_agent_with_dev_main_builder().: Module descriptor automata.core.agent.tests.conftest not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.agent.tests.test_automata_agent`/__init__:: Module descriptor automata.core.agent.tests.test_automata_agent not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.agent.tests.test_automata_agent`/test_build_tool_message().: Module descriptor automata.core.agent.tests.test_automata_agent not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.agent.tests.test_automata_agent`/test_build_tool_message().(automata_agent_config_builder): Module descriptor automata.core.agent.tests.test_automata_agent not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.agent.tests.test_automata_agent`/test_build_initial_messages().: Module descriptor automata.core.agent.tests.test_automata_agent not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.agent.tests.test_automata_agent`/test_build_initial_messages().(automata_agent): Module descriptor automata.core.agent.tests.test_automata_agent not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.agent.tests.test_automata_agent`/test_init_database().: Module descriptor automata.core.agent.tests.test_automata_agent not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.agent.tests.test_automata_agent`/test_init_database().(automata_agent): Module descriptor automata.core.agent.tests.test_automata_agent not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.agent.tests.test_automata_agent`/test_save_and_load_interaction().: Module descriptor automata.core.agent.tests.test_automata_agent not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.agent.tests.test_automata_agent`/test_save_and_load_interaction().(automata_agent): Module descriptor automata.core.agent.tests.test_automata_agent not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.agent.tests.test_automata_agent`/test_iter_task_without_api_call().: Module descriptor automata.core.agent.tests.test_automata_agent not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.agent.tests.test_automata_agent`/test_iter_task_without_api_call().(mock_openai_chatcompletion_create): Module descriptor automata.core.agent.tests.test_automata_agent not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.agent.tests.test_automata_agent`/test_iter_task_without_api_call().(automata_agent): Module descriptor automata.core.agent.tests.test_automata_agent not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.agent.tests.test_automata_agent`/mock_openai_response_with_completion_message().: Module descriptor automata.core.agent.tests.test_automata_agent not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.agent.tests.test_automata_agent`/test_iter_task_with_completion_message().: Module descriptor automata.core.agent.tests.test_automata_agent not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.agent.tests.test_automata_agent`/test_iter_task_with_completion_message().(mock_openai_chatcompletion_create): Module descriptor automata.core.agent.tests.test_automata_agent not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.agent.tests.test_automata_agent`/test_iter_task_with_completion_message().(api_response): Module descriptor automata.core.agent.tests.test_automata_agent not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.agent.tests.test_automata_agent`/test_iter_task_with_completion_message().(automata_agent): Module descriptor automata.core.agent.tests.test_automata_agent not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.agent.tests.test_automata_agent`/mock_openai_response_with_completion_tool_message_to_parse().: Module descriptor automata.core.agent.tests.test_automata_agent not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.agent.tests.test_automata_agent`/test_iter_task_with_parsed_completion_message().: Module descriptor automata.core.agent.tests.test_automata_agent not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.agent.tests.test_automata_agent`/test_iter_task_with_parsed_completion_message().(mock_openai_chatcompletion_create): Module descriptor automata.core.agent.tests.test_automata_agent not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.agent.tests.test_automata_agent`/test_iter_task_with_parsed_completion_message().(api_response): Module descriptor automata.core.agent.tests.test_automata_agent not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.agent.tests.test_automata_agent`/test_iter_task_with_parsed_completion_message().(automata_agent): Module descriptor automata.core.agent.tests.test_automata_agent not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.agent.tests.test_automata_agent`/mock_openai_response_with_completion_agent_message_to_parse().: Module descriptor automata.core.agent.tests.test_automata_agent not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.agent.tests.test_automata_agent`/test_iter_task_with_parsed_completion_message_2().: Module descriptor automata.core.agent.tests.test_automata_agent not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.agent.tests.test_automata_agent`/test_iter_task_with_parsed_completion_message_2().(mock_openai_chatcompletion_create): Module descriptor automata.core.agent.tests.test_automata_agent not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.agent.tests.test_automata_agent`/test_iter_task_with_parsed_completion_message_2().(api_response): Module descriptor automata.core.agent.tests.test_automata_agent not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.agent.tests.test_automata_agent`/test_iter_task_with_parsed_completion_message_2().(automata_agent_with_dev_main_builder): Module descriptor automata.core.agent.tests.test_automata_agent not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.agent.tests.test_automata_agent`/test_iter_task_with_parsed_completion_message_main_2().: Module descriptor automata.core.agent.tests.test_automata_agent not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.agent.tests.test_automata_agent`/test_iter_task_with_parsed_completion_message_main_2().(mock_openai_chatcompletion_create): Module descriptor automata.core.agent.tests.test_automata_agent not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.agent.tests.test_automata_agent`/test_iter_task_with_parsed_completion_message_main_2().(api_response): Module descriptor automata.core.agent.tests.test_automata_agent not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.agent.tests.test_automata_agent`/test_iter_task_with_parsed_completion_message_main_2().(automata_agent_with_dev_main_builder): Module descriptor automata.core.agent.tests.test_automata_agent not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.agent.tests.test_automata_agent_builder`/__init__:: Module descriptor automata.core.agent.tests.test_automata_agent_builder not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.agent.tests.test_automata_agent_builder`/test_automata_agent_init().: Module descriptor automata.core.agent.tests.test_automata_agent_builder not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.agent.tests.test_automata_agent_builder`/test_automata_agent_init().(automata_agent): Module descriptor automata.core.agent.tests.test_automata_agent_builder not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.agent.tests.test_automata_agent_builder`/test_automata_agent_iter_task().: Module descriptor automata.core.agent.tests.test_automata_agent_builder not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.agent.tests.test_automata_agent_builder`/test_automata_agent_iter_task().(automata_agent): Module descriptor automata.core.agent.tests.test_automata_agent_builder not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.agent.tests.test_automata_agent_builder`/test_builder_default_config().: Module descriptor automata.core.agent.tests.test_automata_agent_builder not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.agent.tests.test_automata_agent_builder`/test_builder_default_config().(automata_agent_config_builder): Module descriptor automata.core.agent.tests.test_automata_agent_builder not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.agent.tests.test_automata_agent_builder`/test_builder_provided_parameters_override_defaults().: Module descriptor automata.core.agent.tests.test_automata_agent_builder not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.agent.tests.test_automata_agent_builder`/test_builder_provided_parameters_override_defaults().(automata_agent_config_builder): Module descriptor automata.core.agent.tests.test_automata_agent_builder not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.agent.tests.test_automata_agent_builder`/test_builder_accepts_all_fields().: Module descriptor automata.core.agent.tests.test_automata_agent_builder not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.agent.tests.test_automata_agent_builder`/test_builder_accepts_all_fields().(automata_agent_config_builder): Module descriptor automata.core.agent.tests.test_automata_agent_builder not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.agent.tests.test_automata_agent_builder`/test_builder_creates_proper_instance().: Module descriptor automata.core.agent.tests.test_automata_agent_builder not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.agent.tests.test_automata_agent_builder`/test_builder_creates_proper_instance().(automata_agent_config_builder): Module descriptor automata.core.agent.tests.test_automata_agent_builder not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.agent.tests.test_automata_agent_builder`/test_builder_invalid_input_types().: Module descriptor automata.core.agent.tests.test_automata_agent_builder not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.agent.tests.test_automata_agent_builder`/test_builder_invalid_input_types().(automata_agent_config_builder): Module descriptor automata.core.agent.tests.test_automata_agent_builder not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.agent.tests.test_automata_agent_builder`/test_config_loading_different_versions().: Module descriptor automata.core.agent.tests.test_automata_agent_builder not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.agent.tests.test_automata_helpers`/__init__:: Module descriptor automata.core.agent.tests.test_automata_helpers not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.agent.tests.test_automata_helpers`/test_extract_actions_0().: Module descriptor automata.core.agent.tests.test_automata_helpers not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.agent.tests.test_automata_helpers`/test_extract_actions_1().: Module descriptor automata.core.agent.tests.test_automata_helpers not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.agent.tests.test_automata_helpers`/test_extract_actions_2().: Module descriptor automata.core.agent.tests.test_automata_helpers not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.agent.tests.test_automata_helpers`/test_extract_actions_3().: Module descriptor automata.core.agent.tests.test_automata_helpers not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.agent.tests.test_automata_helpers`/test_extract_actions_4().: Module descriptor automata.core.agent.tests.test_automata_helpers not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.agent.tests.test_automata_helpers`/test_extract_actions_5().: Module descriptor automata.core.agent.tests.test_automata_helpers not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.agent.tests.test_automata_helpers`/test_extract_actions_5().(automata_agent): Module descriptor automata.core.agent.tests.test_automata_helpers not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.agent.tests.test_automata_helpers`/test_extract_actions_6().: Module descriptor automata.core.agent.tests.test_automata_helpers not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.agent.tests.test_automata_helpers`/test_extract_actions_6().(automata_agent): Module descriptor automata.core.agent.tests.test_automata_helpers not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.agent.tests.test_automata_helpers`/test_extract_actions_7().: Module descriptor automata.core.agent.tests.test_automata_helpers not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.agent.tests.test_automata_helpers`/test_extract_actions_8().: Module descriptor automata.core.agent.tests.test_automata_helpers not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#: Symbol Symbol(scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#, scip-python, Package(python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43), (Descriptor(automata.core.base.base_tool, 1), Descriptor(SilentCallbackManager, 2))) not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#on_tool_start().: Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#on_tool_start().(self): Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#on_tool_start().(tool_info): Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#on_tool_start().(tool_input): Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#on_tool_start().(args): Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#on_tool_start().(kwargs): Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#on_tool_error().: Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#on_tool_error().(self): Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#on_tool_error().(error): Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#on_tool_error().(args): Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#on_tool_error().(kwargs): Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#on_tool_end().: Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#on_tool_end().(self): Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#on_tool_end().(observation): Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#on_tool_end().(args): Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#on_tool_end().(kwargs): Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#on_tool_start_async().: Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#on_tool_start_async().(self): Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#on_tool_start_async().(tool_info): Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#on_tool_start_async().(tool_input): Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#on_tool_start_async().(args): Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#on_tool_start_async().(kwargs): Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#on_tool_error_async().: Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#on_tool_error_async().(self): Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#on_tool_error_async().(error): Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#on_tool_error_async().(args): Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#on_tool_error_async().(kwargs): Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#on_tool_end_async().: Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#on_tool_end_async().(self): Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#on_tool_end_async().(observation): Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#on_tool_end_async().(args): Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#on_tool_end_async().(kwargs): Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#add_handler().: Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#add_handler().(self): Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#add_handler().(args): Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#add_handler().(kwargs): Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#on_agent_action().: Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#on_agent_action().(self): Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#on_agent_action().(args): Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#on_agent_action().(kwargs): Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#on_agent_finish().: Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#on_agent_finish().(self): Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#on_agent_finish().(args): Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#on_agent_finish().(kwargs): Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#on_chain_end().: Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#on_chain_end().(self): Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#on_chain_end().(args): Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#on_chain_end().(kwargs): Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#on_chain_error().: Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#on_chain_error().(self): Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#on_chain_error().(args): Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#on_chain_error().(kwargs): Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#on_chain_start().: Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#on_chain_start().(self): Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#on_chain_start().(args): Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#on_chain_start().(kwargs): Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#on_llm_end().: Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#on_llm_end().(self): Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#on_llm_end().(args): Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#on_llm_end().(kwargs): Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#on_llm_error().: Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#on_llm_error().(self): Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#on_llm_error().(args): Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#on_llm_error().(kwargs): Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#on_llm_new_token().: Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#on_llm_new_token().(self): Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#on_llm_new_token().(args): Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#on_llm_new_token().(kwargs): Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#on_llm_start().: Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#on_llm_start().(self): Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#on_llm_start().(args): Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#on_llm_start().(kwargs): Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#on_text().: Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#on_text().(self): Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#on_text().(args): Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#on_text().(kwargs): Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#remove_handler().: Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#remove_handler().(self): Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#remove_handler().(args): Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#remove_handler().(kwargs): Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#set_handlers().: Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#set_handlers().(self): Method descriptor found without module or class descriptor
#  28%|███████████████████████████████████████████████▎                                                                                                                          | 599/2150 [00:27<00:07, 220.35it/s]
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#set_handlers().(args): Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/SilentCallbackManager#set_handlers().(kwargs): Method descriptor found without module or class descriptor
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/BaseTool#set_callback_manager().: Symbol Symbol(scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/BaseTool#set_callback_manager()., scip-python, Package(python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43), (Descriptor(automata.core.base.base_tool, 1), Descriptor(BaseTool, 2), Descriptor(set_callback_manager, 4))) not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/BaseTool#set_callback_manager().(cls): Symbol Symbol(scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/BaseTool#set_callback_manager().(cls), scip-python, Package(python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43), (Descriptor(automata.core.base.base_tool, 1), Descriptor(BaseTool, 2), Descriptor(set_callback_manager, 4), Descriptor(cls, 6))) not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/BaseTool#set_callback_manager().(callback_manager): Symbol Symbol(scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.base_tool`/BaseTool#set_callback_manager().(callback_manager), scip-python, Package(python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43), (Descriptor(automata.core.base.base_tool, 1), Descriptor(BaseTool, 2), Descriptor(set_callback_manager, 4), Descriptor(callback_manager, 6))) not found
#  39%|██████████████████████████████████████████████████████████████████                                                                                                        | 835/2150 [00:33<00:08, 159.73it/s]
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.tests.test_base_tool`/__init__:: Module descriptor automata.core.base.tests.test_base_tool not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.tests.test_base_tool`/MockTool#: Module descriptor automata.core.base.tests.test_base_tool not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.tests.test_base_tool`/MockTool#_run().: Module descriptor automata.core.base.tests.test_base_tool not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.tests.test_base_tool`/MockTool#_run().(self): Module descriptor automata.core.base.tests.test_base_tool not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.tests.test_base_tool`/MockTool#_run().(tool_input): Module descriptor automata.core.base.tests.test_base_tool not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.tests.test_base_tool`/MockTool#_arun().: Module descriptor automata.core.base.tests.test_base_tool not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.tests.test_base_tool`/MockTool#_arun().(self): Module descriptor automata.core.base.tests.test_base_tool not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.tests.test_base_tool`/MockTool#_arun().(tool_input): Module descriptor automata.core.base.tests.test_base_tool not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.tests.test_base_tool`/mock_tool().: Module descriptor automata.core.base.tests.test_base_tool not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.tests.test_base_tool`/test_silent_callback_manager().: Module descriptor automata.core.base.tests.test_base_tool not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.tests.test_base_tool`/test_base_tool_instantiation().: Module descriptor automata.core.base.tests.test_base_tool not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.tests.test_base_tool`/test_base_tool_instantiation().(mock_tool): Module descriptor automata.core.base.tests.test_base_tool not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.tests.test_base_tool`/test_base_tool_run().: Module descriptor automata.core.base.tests.test_base_tool not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.tests.test_base_tool`/test_base_tool_run().(mock_tool): Module descriptor automata.core.base.tests.test_base_tool not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.tests.test_base_tool`/test_base_tool_arun().: Module descriptor automata.core.base.tests.test_base_tool not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.tests.test_base_tool`/test_base_tool_arun().(mock_tool): Module descriptor automata.core.base.tests.test_base_tool not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.tests.test_base_tool`/test_base_tool_set_callback_manager().: Module descriptor automata.core.base.tests.test_base_tool not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.tests.test_base_tool`/test_base_tool_call().: Module descriptor automata.core.base.tests.test_base_tool not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.tests.test_base_tool`/test_base_tool_call().(mock_tool): Module descriptor automata.core.base.tests.test_base_tool not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.tests.test_tool`/__init__:: Module descriptor automata.core.base.tests.test_tool not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.tests.test_tool`/TestTool#: Module descriptor automata.core.base.tests.test_tool not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.tests.test_tool`/TestTool#_run().: Module descriptor automata.core.base.tests.test_tool not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.tests.test_tool`/TestTool#_run().(self): Module descriptor automata.core.base.tests.test_tool not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.core.base.tests.test_tool`/TestTool#_run().(tool_input): Module descriptor automata.core.base.tests.test_tool not found
# ...
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.tools.search.symbol_rank.tests.test_symbol_embedding_map`/test_get_embedding_sets_correct_result().(monkeypatch): Module descriptor automata.tools.search.symbol_rank.tests.test_symbol_embedding_map not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.tools.search.symbol_rank.tests.test_symbol_embedding_map`/test_get_embedding_sets_correct_result().(mock_embedding): Module descriptor automata.tools.search.symbol_rank.tests.test_symbol_embedding_map not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.tools.search.symbol_rank.tests.test_symbol_embedding_map`/test_get_embedding_sets_correct_result().(mock_simple_method_symbols): Module descriptor automata.tools.search.symbol_rank.tests.test_symbol_embedding_map not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.tools.search.symbol_rank.tests.test_symbol_embedding_map`/test_get_embedding_sets_correct_result().(mock_simple_class_symbols): Module descriptor automata.tools.search.symbol_rank.tests.test_symbol_embedding_map not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.tools.search.symbol_rank.tests.test_symbol_embedding_map`/test_get_embedding_sets_correct_result().(mock_symbol_converter): Module descriptor automata.tools.search.symbol_rank.tests.test_symbol_embedding_map not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.tools.search.symbol_rank.tests.test_symbol_rank`/__init__:: Module descriptor automata.tools.search.symbol_rank.tests.test_symbol_rank not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.tools.search.symbol_rank.tests.test_symbol_rank`/test_generate_random_graph().: Module descriptor automata.tools.search.symbol_rank.tests.test_symbol_rank not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.tools.search.symbol_rank.tests.test_symbol_rank`/test_pagerank_config_validation().: Module descriptor automata.tools.search.symbol_rank.tests.test_symbol_rank not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.tools.search.symbol_rank.tests.test_symbol_rank`/test_prepare_initial_ranks().: Module descriptor automata.tools.search.symbol_rank.tests.test_symbol_rank not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.tools.search.symbol_rank.tests.test_symbol_rank`/test_get_ranks().: Module descriptor automata.tools.search.symbol_rank.tests.test_symbol_rank not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.tools.search.symbol_rank.tests.test_symbol_rank`/test_get_ranks_small_graph().: Module descriptor automata.tools.search.symbol_rank.tests.test_symbol_rank not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.tools.search.tests.conftest`/__init__:: Module descriptor automata.tools.search.tests.conftest not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.tools.search.tests.conftest`/symbols().: Module descriptor automata.tools.search.tests.conftest not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.tools.search.tests.conftest`/symbol_converter().: Module descriptor automata.tools.search.tests.conftest not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.tools.search.tests.conftest`/symbol_graph().: Module descriptor automata.tools.search.tests.conftest not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.tools.search.tests.conftest`/symbol_graph().(symbol_converter): Module descriptor automata.tools.search.tests.conftest not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.tools.search.tests.conftest`/symbol_graph_mock().: Module descriptor automata.tools.search.tests.conftest not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.tools.search.tests.conftest`/symbol_graph_mock().(mocker): Module descriptor automata.tools.search.tests.conftest not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.tools.search.tests.conftest`/symbol_searcher().: Module descriptor automata.tools.search.tests.conftest not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.tools.search.tests.conftest`/symbol_searcher().(symbol_converter): Module descriptor automata.tools.search.tests.conftest not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.tools.search.tests.conftest`/symbol_searcher().(symbol_graph_mock): Module descriptor automata.tools.search.tests.conftest not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.tools.search.tests.test_symbol_graph`/__init__:: Module descriptor automata.tools.search.tests.test_symbol_graph not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.tools.search.tests.test_symbol_graph`/test_get_all_files().: Module descriptor automata.tools.search.tests.test_symbol_graph not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.tools.search.tests.test_symbol_graph`/test_get_all_files().(symbol_graph): Module descriptor automata.tools.search.tests.test_symbol_graph not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.tools.search.tests.test_symbol_graph`/test_get_all_symbols().: Module descriptor automata.tools.search.tests.test_symbol_graph not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.tools.search.tests.test_symbol_graph`/test_get_all_symbols().(symbol_graph): Module descriptor automata.tools.search.tests.test_symbol_graph not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.tools.search.tests.test_symbol_graph`/test_get_all_symbols().(symbols): Module descriptor automata.tools.search.tests.test_symbol_graph not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.tools.search.tests.test_symbol_graph`/test_get_symbol_references().: Module descriptor automata.tools.search.tests.test_symbol_graph not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.tools.search.tests.test_symbol_graph`/test_get_symbol_references().(symbol_graph): Module descriptor automata.tools.search.tests.test_symbol_graph not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.tools.search.tests.test_symbol_graph`/test_get_symbol_references().(symbols): Module descriptor automata.tools.search.tests.test_symbol_graph not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.tools.search.tests.test_symbol_graph`/test_get_symbols_along_path().: Module descriptor automata.tools.search.tests.test_symbol_graph not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.tools.search.tests.test_symbol_graph`/test_get_symbols_along_path().(symbol_graph): Module descriptor automata.tools.search.tests.test_symbol_graph not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.tools.search.tests.test_symbol_graph`/test_get_symbol_context().: Module descriptor automata.tools.search.tests.test_symbol_graph not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.tools.search.tests.test_symbol_graph`/test_get_symbol_context().(symbol_graph): Module descriptor automata.tools.search.tests.test_symbol_graph not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.tools.search.tests.test_symbol_graph`/test_get_symbol_context().(symbols): Module descriptor automata.tools.search.tests.test_symbol_graph not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.tools.search.tests.test_symbol_parser`/__init__:: Module descriptor automata.tools.search.tests.test_symbol_parser not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.tools.search.tests.test_symbol_parser`/test_parse_symbol().: Module descriptor automata.tools.search.tests.test_symbol_parser not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.tools.search.tests.test_symbol_parser`/test_parse_symbol().(symbols): Module descriptor automata.tools.search.tests.test_symbol_parser not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.tools.search.tests.test_symbol_parser`/test_is_global_symbol().: Module descriptor automata.tools.search.tests.test_symbol_parser not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.tools.search.tests.test_symbol_parser`/test_is_global_symbol().(symbols): Module descriptor automata.tools.search.tests.test_symbol_parser not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.tools.search.tests.test_symbol_parser`/test_is_local_symbol().: Module descriptor automata.tools.search.tests.test_symbol_parser not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.tools.search.tests.test_symbol_parser`/test_is_local_symbol().(symbols): Module descriptor automata.tools.search.tests.test_symbol_parser not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.tools.search.tests.test_symbol_parser`/_unparse().: Module descriptor automata.tools.search.tests.test_symbol_parser not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.tools.search.tests.test_symbol_parser`/_unparse().(symbol): Module descriptor automata.tools.search.tests.test_symbol_parser not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.tools.search.tests.test_symbol_parser`/test_unparse_symbol().: Module descriptor automata.tools.search.tests.test_symbol_parser not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.tools.search.tests.test_symbol_parser`/test_unparse_symbol().(symbols): Module descriptor automata.tools.search.tests.test_symbol_parser not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.tools.search.tests.test_symbol_search`/__init__:: Module descriptor automata.tools.search.tests.test_symbol_search not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.tools.search.tests.test_symbol_search`/test_retrieve_source_code_by_symbol().: Module descriptor automata.tools.search.tests.test_symbol_search not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.tools.search.tests.test_symbol_search`/test_retrieve_source_code_by_symbol().(symbols): Module descriptor automata.tools.search.tests.test_symbol_search not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.tools.search.tests.test_symbol_search`/test_retrieve_source_code_by_symbol().(symbol_searcher): Module descriptor automata.tools.search.tests.test_symbol_search not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.tools.search.tests.test_symbol_search`/test_retrieve_source_code_by_symbol().(symbol_graph_mock): Module descriptor automata.tools.search.tests.test_symbol_search not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.tools.search.tests.test_symbol_search`/test_symbol_search().: Module descriptor automata.tools.search.tests.test_symbol_search not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.tools.search.tests.test_symbol_search`/test_symbol_search().(symbols): Module descriptor automata.tools.search.tests.test_symbol_search not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.tools.search.tests.test_symbol_search`/test_symbol_search().(symbol_searcher): Module descriptor automata.tools.search.tests.test_symbol_search not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.tools.search.tests.test_symbol_search`/test_symbol_search().(symbol_graph_mock): Module descriptor automata.tools.search.tests.test_symbol_search not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.tools.search.tests.test_symbol_search`/test_exact_search().: Module descriptor automata.tools.search.tests.test_symbol_search not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.tools.search.tests.test_symbol_search`/test_exact_search().(symbol_searcher): Module descriptor automata.tools.search.tests.test_symbol_search not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.tools.search.tests.test_symbol_search`/test_exact_search().(symbol_graph_mock): Module descriptor automata.tools.search.tests.test_symbol_search not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.tools.search.tests.test_symbol_search`/test_find_and_replace().: Module descriptor automata.tools.search.tests.test_symbol_search not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.tools.search.tests.test_symbol_search`/test_find_and_replace().(symbol_searcher): Module descriptor automata.tools.search.tests.test_symbol_search not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.tools.search.tests.test_symbol_search`/test_find_and_replace().(symbol_graph_mock): Module descriptor automata.tools.search.tests.test_symbol_search not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.tools.search.tests.test_symbol_search`/test_process_query().: Module descriptor automata.tools.search.tests.test_symbol_search not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.tools.search.tests.test_symbol_search`/test_process_query().(symbols): Module descriptor automata.tools.search.tests.test_symbol_search not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.tools.search.tests.test_symbol_search`/test_process_query().(symbol_searcher): Module descriptor automata.tools.search.tests.test_symbol_search not found
# Error processing scip-python python automata 4d57f302bbe1f8b007a4007033d6e3f16b8c1d43 `automata.tools.search.tests.test_symbol_search`/test_process_query().(symbol_graph_mock): Module descriptor automata.tools.search.tests.test_symbol_search not found

# %%
import networkx as nx
from pyvis.network import Network

# Create a copy of the graph to avoid modifying the original.
symbol_subgraph_copy = symbol_subgraph.copy()

# Relabel all nodes to strings.
mapping = {node: str(node.uri).split("/")[1] for node in symbol_subgraph_copy.nodes()}
symbol_subgraph_string_nodes = nx.relabel_nodes(symbol_subgraph_copy, mapping)

# Build a subgraph
sub_node = "AutomataAgent#"
ego_graph = nx.ego_graph(symbol_subgraph_string_nodes, sub_node)

# %%
# Create a pyvis network object
nt = Network('1000px', '1000px', notebook=True)

# Set the options
options = {
    'physics': {
        'barnesHut': {
            'gravitationalConstant': -30000,
            'centralGravity': 0.3,
            'springLength': 95,
            'springConstant': 0.04,
            'damping': 0.09,
            'avoidOverlap': 0.1
        },
        'minVelocity': 0.75,
    }
}

options_json = json.dumps(options)
nt.set_options(options_json)

# Produce the network and show
nt.from_nx(ego_graph)
nt.show('nx.html')
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# nx.html
#         <iframe
#             width="1000px"
#             height="1000px"
#             src="nx.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
